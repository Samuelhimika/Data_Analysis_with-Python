# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns


Year = data['Year']
Males = data['Males']
Females = ['Females']
Total = data['Total']


x= r"C:\Users\TRUTH & JUSTICE\Desktop\Cs-Students.csv"
data = pd.read_csv(x)
data.head()
# Out:
#    Year  Males  Females  Total
# 0  2023    678      760   3461
# 1  2022    546      546   3114
# 2  2021    678      657   1335
# 3  2020    345      457    802
# 4  2019    167      145    312

# %%
x_index =np.arange( len(Year))





plt.plot(x_index, Total, color = 'red')
plt.xticks(ticks=x_index, labels=Year)
plt.title('Students offering Cs in the region per year')
plt.xlabel('Year')
plt.ylabel('Total')
plt.tight_layout()
plt.show()
